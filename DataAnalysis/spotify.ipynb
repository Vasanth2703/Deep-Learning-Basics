# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/vasanth/Python/Spotify_Song_Attributes.csv')

# %%
df.head()
# Out:
#                                            trackName  \
# 0                                           "Honest"
# 1  "In The Hall Of The Mountain King" from Peer G...
# 2                                 #BrooklynBloodPop!
# 3                                                $10
# 4                         (I Just) Died In Your Arms
#
#                   artistName  msPlayed              genre  danceability  \
# 0               Nico Collins    191772                NaN         0.476
# 1  London Symphony Orchestra   1806234  british orchestra         0.475
# 2                       SyKo    145610         glitchcore         0.691
# 3               Good Morning     25058   experimental pop         0.624
# 4               Cutting Crew   5504949         album rock         0.625
#
#    energy   key  loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 0   0.799   4.0    -4.939   0.0       0.2120  ...    0.2570    0.577  162.139
# ...

# %%
df.shape
# Out:
# (10080, 22)

# %%
df.dtypes
# Out:
# trackName            object
# artistName           object
# msPlayed              int64
# genre                object
# danceability        float64
# energy              float64
# key                 float64
# loudness            float64
# mode                float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms         float64
# time_signature      float64
# dtype: object

# %%
df['genre']
# Out:
# 0                      NaN
# 1        british orchestra
# 2               glitchcore
# 3         experimental pop
# 4               album rock
#                ...
# 10075             folk-pop
# 10076                  NaN
# 10077            sad lo-fi
# 10078              art pop
# 10079              pop rap
# Name: genre, Length: 10080, dtype: object

# %%
df['danceability']
# Out:
# 0        0.476
# 1        0.475
# 2        0.691
# 3        0.624
# 4        0.625
#          ...
# 10075    0.537
# 10076      NaN
# 10077    0.282
# 10078    0.632
# 10079    0.560
# Name: danceability, Length: 10080, dtype: float64

# %%
mask=df['danceability']>0.600
df[mask]
# Out:
#                         trackName     artistName  msPlayed             genre  \
# 2              #BrooklynBloodPop!           SyKo    145610        glitchcore
# 3                             $10   Good Morning     25058  experimental pop
# 4      (I Just) Died In Your Arms   Cutting Crew   5504949        album rock
# 5                   (L)only Child    salem ilese   2237969             alt z
# 6                           (lol)   Eren Cannata    441335       guitar case
# ...                           ...            ...       ...               ...
# 10068               Young & Alive          Bazzi     38421               pop
# 10070          Young Dumb & Broke         Khalid    484456               pop
# 10073                     Younger     Jonas Blue   2560215               pop
# 10074                     Younger           Ruel   5272303             alt z
# 10078                  Your Power  Billie Eilish    988224           art pop
#
# ...

# %%
mask.size
# Out:
# 10080

# %%
a=df.iloc[0:100]
b=df.iloc[0:100]

# %%
df['msPlayed']
# Out:
# 0         191772
# 1        1806234
# 2         145610
# 3          25058
# 4        5504949
#           ...
# 10075     668478
# 10076     304382
# 10077      97600
# 10078     988224
# 10079     213626
# Name: msPlayed, Length: 10080, dtype: int64

# %%
m=df['msPlayed'].max()

# %%
m
# Out:
# 158367130

# %%
mask=df['msPlayed']==df['msPlayed'].max()
df[mask]
# Out:
#                  trackName artistName   msPlayed  genre  danceability  energy  \
# 4194  Sparkle - movie ver.   RADWIMPS  158367130  j-pop         0.372   0.426
# 9234  Sparkle - movie ver.   RADWIMPS  158367130  j-pop         0.372   0.426
#
#        key  loudness  mode  speechiness  ...  liveness  valence    tempo  \
# 4194  11.0    -8.421   1.0       0.0339  ...     0.109    0.287  123.993
# 9234  11.0    -8.421   1.0       0.0339  ...     0.109    0.287  123.993
#
#                 type                      id  \
# 4194  audio_features  3A4FRzgve9BjfKbvVXRIFO
# 9234  audio_features  3A4FRzgve9BjfKbvVXRIFO
#
#                                        uri  \
# 4194  spotify:track:3A4FRzgve9BjfKbvVXRIFO
# 9234  spotify:track:3A4FRzgve9BjfKbvVXRIFO
#
#                                              track_href  \
# 4194  https://api.spotify.com/v1/tracks/3A4FRzgve9Bj...
# 9234  https://api.spotify.com/v1/tracks/3A4FRzgve9Bj...
#
# ...

# %%
df['genre']
# Out:
# 0                      NaN
# 1        british orchestra
# 2               glitchcore
# 3         experimental pop
# 4               album rock
#                ...
# 10075             folk-pop
# 10076                  NaN
# 10077            sad lo-fi
# 10078              art pop
# 10079              pop rap
# Name: genre, Length: 10080, dtype: object

# %%
mask=df['genre']

# %%
df
# Out:
#                                                trackName  \
# 0                                               "Honest"
# 1      "In The Hall Of The Mountain King" from Peer G...
# 2                                     #BrooklynBloodPop!
# 3                                                    $10
# 4                             (I Just) Died In Your Arms
# ...                                                  ...
# 10075                                 Younger with Time.
# 10076                Your Latest Trick - Remastered 1996
# 10077                Your Love Is My Drug (8 Bit Slowed)
# 10078                                         Your Power
# 10079                            Your Voice / Bethel, NY
#
#                       artistName  msPlayed              genre  danceability  \
# 0                   Nico Collins    191772                NaN         0.476
# 1      London Symphony Orchestra   1806234  british orchestra         0.475
# ...

# %%
mask=df.iloc[0:15]

# %%
mask.plot(x='danceability', y='energy', kind='bar')
# Out:
# <Axes: xlabel='danceability'>

# %%
mask=df.iloc[0:15]
mask.plot(x='danceability', y='energy', kind='bar')
# Out:
# <Axes: xlabel='danceability'>

# %%
plt.pie(df['msPlayed'], labels=df['genre'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 plt.pie(df['msPlayed'], labels=df['genre'])
# ----> 2 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# ...

# %%
mask=df.iloc[0:15]
plt.pie(mask['msPlayed'], labels=mask['genre'])
plt.title('Pie Representation of ms Played and the corresponding genre')
# Out:
# Text(0.5, 1.0, 'Pie Representation of ms Played and the corresponding genre')

# %%
df
# Out:
#                                                trackName  \
# 0                                               "Honest"
# 1      "In The Hall Of The Mountain King" from Peer G...
# 2                                     #BrooklynBloodPop!
# 3                                                    $10
# 4                             (I Just) Died In Your Arms
# ...                                                  ...
# 10075                                 Younger with Time.
# 10076                Your Latest Trick - Remastered 1996
# 10077                Your Love Is My Drug (8 Bit Slowed)
# 10078                                         Your Power
# 10079                            Your Voice / Bethel, NY
#
#                       artistName  msPlayed              genre  danceability  \
# 0                   Nico Collins    191772                NaN         0.476
# 1      London Symphony Orchestra   1806234  british orchestra         0.475
# ...

# %%
mask1=df.nlargest(10, 'msPlayed')
mask1
# Out:
#                                trackName    artistName   msPlayed  \
# 4194                Sparkle - movie ver.      RADWIMPS  158367130
# 9234                Sparkle - movie ver.      RADWIMPS  158367130
# 1001                                 色香水  Yoh kamiyama  109652914
# 6041                                 色香水  Yoh kamiyama  109652914
# 2058                                Gone    Blake Rose  105798353
# 7098                                Gone    Blake Rose  105798353
# 2890                         Lonely City        Mokita  102503285
# 7930                         Lonely City        Mokita  102503285
# 4559  This Town (feat. Sasha Alex Sloan)          Kygo   76360841
# 9599  This Town (feat. Sasha Alex Sloan)          Kygo   76360841
#
#                       genre  danceability  energy   key  loudness  mode  \
# 4194                  j-pop         0.372   0.426  11.0    -8.421   1.0
# 9234                  j-pop         0.372   0.426  11.0    -8.421   1.0
# ...

# %%
mask2=df.nlargest(30, 'msPlayed')
plt.bar(mask2['genre'], mask2['msPlayed'])
plt.xlabel('Genre')
plt.ylabel('ms Played')
plt.title('Genre vs ms Played (Top 30 songs)')

plt.xticks(rotation=90)
plt.figure(figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
plt.bar(mask1['genre'], mask1['msPlayed'], color='green')
plt.xlabel('Genre')
plt.ylabel('ms Played')
plt.title('Genre vs ms Played(Top 10 songs)')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
plt.pie(mask1['msPlayed'], labels=mask1['genre'])
plt.title('Pie Chart showing the distribution of genre vs ms Played')
plt.figure(figsize=(8, 8))

# %%
plt.pie(mask1['energy'], labels=mask1['genre'])
plt.title('Pie Chart showing the distribution of genre vs energy')
plt.figure(figsize=(8, 8))

# %%
plt.bar(mask1['genre'], mask1['energy'])
plt.xticks(rotation=90)
plt.figure(figsize=(8, 8))

# %%
mask1=df.nlargest(10, 'energy')
plt.bar(mask1['genre'], mask1['energy'], color=['green', 'blue', 'red', 'pink'])
plt.xticks(rotation=90)
plt.show()

# %%
mask1=df.nlargest(10, 'msPlayed')
plt.bar(mask1['genre'], mask1['danceability'])
plt.title('Genre vs Danceability')
plt.xticks(rotation=45)

plt.show()

# %%
df
# Out:
#                                                trackName  \
# 0                                               "Honest"
# 1      "In The Hall Of The Mountain King" from Peer G...
# 2                                     #BrooklynBloodPop!
# 3                                                    $10
# 4                             (I Just) Died In Your Arms
# ...                                                  ...
# 10075                                 Younger with Time.
# 10076                Your Latest Trick - Remastered 1996
# 10077                Your Love Is My Drug (8 Bit Slowed)
# 10078                                         Your Power
# 10079                            Your Voice / Bethel, NY
#
#                       artistName  msPlayed              genre  danceability  \
# 0                   Nico Collins    191772                NaN         0.476
# 1      London Symphony Orchestra   1806234  british orchestra         0.475
# ...

# %%
mask1=df.nlargest(40, 'msPlayed')
plt.scatter(mask1['genre'], mask1['msPlayed'], color='green')
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot(x='genre', y='msPlayed', data=df.iloc[0:75], color='green')
plt.xlabel('Genre')
plt.ylabel('ms Played')
plt.xticks(rotation=90)
plt.title('LINE PLOT')
plt.show()

# %%
plt.bar(mask1['tempo'], mask1['loudness'])
plt.xlabel('Tempo')
plt.ylabel('Loudness')
plt.title('Tempo vs Loudness')

plt.show()

# %%
plt.plot(a['danceability'], b['loudness'])

# %%
df.plot(x='danceability', y='energy', kind='bar')
# Out:
# <Axes: xlabel='danceability'>
