# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/vasanth/Python/SpotifyFeatures.csv')
df=df.drop_duplicates(subset=['track_id'])

# %%
df
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# ...       ...                       ...
# 232716   Soul               John Legend
# 232717   Soul                     Belly
# 232719   Soul        Bobby "Blue" Bland
# 232721   Soul  Jr Thomas & The Volcanos
# 232724   Soul            Mint Condition
#
#                                     track_name                track_id  \
# 0                  C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1             Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2               Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3               Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                    Ouverture  0IuslXpMROHdEPvSl1fTQK
# ...

# %%
print(df.columns)
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
mask=df['popularity']==df['popularity'].max()
df[mask]
# Out:
#       genre    artist_name track_name                track_id  popularity  \
# 9027  Dance  Ariana Grande    7 rings  14msK75pk3pA33pzPVNtBF         100
#
#       acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 9027         0.578         0.725       178640   0.321               0.0  C#
#
#       liveness  loudness   mode  speechiness   tempo time_signature  valence
# 9027    0.0884   -10.744  Minor        0.323  70.142            4/4    0.319

# %%
m=df[mask]
m['artist_name']
# Out:
# 9027    Ariana Grande
# Name: artist_name, dtype: object

# %%
mask=df.nlargest(10, 'popularity')
mask
# Out:
#           genre    artist_name                                     track_name  \
# 9027      Dance  Ariana Grande                                        7 rings
# 9026      Dance  Ariana Grande       break up with your girlfriend, i'm bored
# 86951       Rap    Post Malone                                           Wow.
# 66643   Hip-Hop   Daddy Yankee                                      Con Calma
# 9028      Dance         Halsey                                     Without Me
# 9037      Dance        Ava Max                               Sweet but Psycho
# 86953       Rap    Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 107810      Pop      Sam Smith         Dancing With A Stranger (with Normani)
# 107812      Pop     Marshmello                                        Happier
# 107875      Pop     Pedro Capó                                  Calma - Remix
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
plt.bar(mask['key'], mask['popularity'])
plt.show()

# %%
len(df.columns)
# Out:
# 18

# %%
df['genre']
# Out:
# 0         Movie
# 1         Movie
# 2         Movie
# 3         Movie
# 4         Movie
#           ...
# 232716     Soul
# 232717     Soul
# 232719     Soul
# 232721     Soul
# 232724     Soul
# Name: genre, Length: 176774, dtype: object

# %%
unique_values=df['genre'].unique()
print(unique_values)
# Out:
# ['Movie' 'R&B' 'A Capella' 'Alternative' 'Country' 'Dance' 'Electronic'
#  'Anime' 'Folk' 'Blues' 'Opera' 'Hip-Hop' "Children's Music"
#  'Children’s Music' 'Rap' 'Indie' 'Classical' 'Pop' 'Reggae' 'Reggaeton'
#  'Jazz' 'Rock' 'Ska' 'Comedy' 'Soul' 'Soundtrack' 'World']

# %%
unique_counts=df['genre'].value_counts()
print(unique_values)
# Out:
# ['Movie' 'R&B' 'A Capella' 'Alternative' 'Country' 'Dance' 'Electronic'
#  'Anime' 'Folk' 'Blues' 'Opera' 'Hip-Hop' "Children's Music"
#  'Children’s Music' 'Rap' 'Indie' 'Classical' 'Pop' 'Reggae' 'Reggaeton'
#  'Jazz' 'Rock' 'Ska' 'Comedy' 'Soul' 'Soundtrack' 'World']

# %%
plt.pie(unique_values, labels=unique_counts)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.pie(unique_values, labels=unique_counts)
#       2 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
#    2798         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2799     return gca().pie(
#    2800         x, explode=explode, labels=labels, colors=colors,
#    2801         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...

# %%
unique_values=df['genre'].unique()
value_counts=df['genre'].value_counts()
counts_dict=value_counts.to_dict()
counts=[counts_dict.get(value, 0) for value in unique_values]

plt.figure(figsize=(8, 8))
plt.pie(counts, labels=unique_values, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Counts by Unique Values')
plt.axis('equal')
plt.show()

# %%
mask=df['popularity']==df['popularity'].max()
df[mask]
# Out:
#       genre    artist_name track_name                track_id  popularity  \
# 9027  Dance  Ariana Grande    7 rings  14msK75pk3pA33pzPVNtBF         100
#
#       acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 9027         0.578         0.725       178640   0.321               0.0  C#
#
#       liveness  loudness   mode  speechiness   tempo time_signature  valence
# 9027    0.0884   -10.744  Minor        0.323  70.142            4/4    0.319

# %%
mask=df.nlargest(20, 'popularity')
mask
# Out:
#             genre          artist_name  \
# 9027        Dance        Ariana Grande
# 9026        Dance        Ariana Grande
# 86951         Rap          Post Malone
# 66643     Hip-Hop         Daddy Yankee
# 9028        Dance               Halsey
# 9037        Dance              Ava Max
# 86953         Rap          Post Malone
# 107810        Pop            Sam Smith
# 107812        Pop           Marshmello
# 107875        Pop           Pedro Capó
# 9048        Dance             DJ Snake
# 66607     Hip-Hop              J. Cole
# 138916  Reggaeton             Anuel Aa
# 9031        Dance        Ariana Grande
# 9040        Dance            Lady Gaga
# 66608     Hip-Hop            Meek Mill
# 66741     Hip-Hop         Paulo Londra
# 107838        Pop  Panic! At The Disco
# 138915  Reggaeton            Bad Bunny
# 138917  Reggaeton                Ozuna
#
#                                             track_name  \
# 9027                                           7 rings
# ...

# %%
mask['genre']
# Out:
# 9027          Dance
# 9026          Dance
# 86951           Rap
# 66643       Hip-Hop
# 9028          Dance
# 9037          Dance
# 86953           Rap
# 107810          Pop
# 107812          Pop
# 107875          Pop
# 9048          Dance
# 66607       Hip-Hop
# 138916    Reggaeton
# 9031          Dance
# 9040          Dance
# 66608       Hip-Hop
# 66741       Hip-Hop
# 107838          Pop
# 138915    Reggaeton
# 138917    Reggaeton
# Name: genre, dtype: object

# %%
unique_values=mask['genre'].unique()
value_counts=mask['genre'].value_counts()
counts_dict=value_counts.to_dict()
counts=[counts_dict.get(value, 0) for value in unique_values]

plt.pie(counts, labels=unique_values, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart showing the top genre songs distribution')
plt.axis('equal')
plt.show()

# %%
df.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
unique_values
# Out:
# array(['Dance', 'Rap', 'Hip-Hop', 'Pop', 'Reggaeton'], dtype=object)

# %%
selected_rows=df[df['genre']=='Dance']
print(selected_rows)
# Out:
#        genre    artist_name                                track_name  \
# 9026   Dance  Ariana Grande  break up with your girlfriend, i'm bored
# 9027   Dance  Ariana Grande                                   7 rings
# 9028   Dance         Halsey                                Without Me
# 9029   Dance  Ariana Grande                                     needy
# 9030   Dance  Ariana Grande                                      NASA
# ...      ...            ...                                       ...
# 22164  Dance        Madonna                        Beautiful Stranger
# 22165  Dance           Cher                                       SOS
# 22166  Dance          Wisin                                     Saoco
# 22167  Dance       Bobby V.                                   Tell Me
# 22168  Dance  Avril Lavigne                                 He Wasn't
#
#                      track_id  popularity  acousticness  danceability  \
# ...

# %%
m1=selected_rows['danceability'].mean()
m1
# Out:
# 0.6419739413680782

# %%
selected_rows=df[df['genre']=='Pop']
m2=selected_rows['danceability'].mean()
m2
# Out:
# 0.6050968142325197

# %%
selected_rows=df[df['genre']=='Rap']
m3=selected_rows['danceability'].mean()
m3
# Out:
# 0.7038688186813188

# %%
selected_rows=df[df['genre']=='Hip-Hop']
m4=selected_rows['danceability'].mean()
m4
# Out:
# 0.7276407662215028

# %%
selected_rows=df[df['genre']=='Reggaeton']
m5=selected_rows['danceability'].mean()
m5
# Out:
# 0.7302526611299568

# %%
selected_rows=df[df['genre']=='Indie']
m6=selected_rows['danceability'].mean()
m6
# Out:
# 0.5737702531645569

# %%
m=[m1, m2, m3, m4, m5, m6]

plt.bar(unique_values, m)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Genre')
plt.ylabel('Danceability')

plt.title('Genre vs Danceability')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 3
#       1 m=[m1, m2, m3, m4, m5, m6]
# ----> 3 plt.bar(unique_values, m)
#       4 plt.xticks(rotation=90)
#       5 plt.grid(axis='y', linestyle='--', alpha=0.7)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
# ...

# %%
df.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
df
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# ...       ...                       ...
# 232716   Soul               John Legend
# 232717   Soul                     Belly
# 232719   Soul        Bobby "Blue" Bland
# 232721   Soul  Jr Thomas & The Volcanos
# 232724   Soul            Mint Condition
#
#                                     track_name                track_id  \
# 0                  C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1             Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2               Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3               Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                    Ouverture  0IuslXpMROHdEPvSl1fTQK
# ...

# %%
df=df.drop_duplicates(subset=['track_id'])

# %%
df
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# ...       ...                       ...
# 232716   Soul               John Legend
# 232717   Soul                     Belly
# 232719   Soul        Bobby "Blue" Bland
# 232721   Soul  Jr Thomas & The Volcanos
# 232724   Soul            Mint Condition
#
#                                     track_name                track_id  \
# 0                  C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1             Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2               Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3               Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                    Ouverture  0IuslXpMROHdEPvSl1fTQK
# ...

# %%
mask=df.nlargest(10, 'popularity')

# %%
# Assuming you already have a DataFrame named 'df'
# Replace 'column_name' with the actual name of the column you want to check for unique values

# Get unique values
unique_values = mask['genre'].unique()

# Get counts of unique values
value_counts = mask['danceability'].value_counts()

# Convert value_counts Series to a dictionary for easy access to counts
counts_dict = value_counts.to_dict()

# Convert counts_dict to a list of counts based on unique_values order
counts = [counts_dict.get(value, 0) for value in unique_values]

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=unique_values, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Counts by Unique Values')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()
# Out:
# /home/vasanth/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3193: RuntimeWarning: invalid value encountered in divide
#   x = x / sx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 18
#      16 # Plotting the pie chart
#      17 plt.figure(figsize=(8, 8))
# ---> 18 plt.pie(counts, labels=unique_values, autopct='%1.1f%%', startangle=140)
#      19 plt.title('Pie Chart of Counts by Unique Values')
#      20 plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
# ...

# %%
sns.set(style='whitegrid')
mask=df.nlargest(20, 'popularity')
data={
    'Categories': mask['key'], 
    'Values': mask['popularity']
}
plt.figure(figsize=(8, 8))
sns.barplot(x='Categories', y='Values', data=data, palette='viridis')
plt.xlabel('Key', fontsize=12)
plt.ylabel('Popularity', fontsize=12)
plt.title('Key vs Popularity', fontsize=14)

for index, value in enumerate(data['Values']):
    plt.text(index, value, str(value), ha='center', va='bottom', fontsize=10)
plt.show()

# %%
mask=df.nlargest(10, 'popularity')
mask
# Out:
#           genre    artist_name                                     track_name  \
# 9027      Dance  Ariana Grande                                        7 rings
# 9026      Dance  Ariana Grande       break up with your girlfriend, i'm bored
# 86951       Rap    Post Malone                                           Wow.
# 66643   Hip-Hop   Daddy Yankee                                      Con Calma
# 9028      Dance         Halsey                                     Without Me
# 9037      Dance        Ava Max                               Sweet but Psycho
# 86953       Rap    Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 107810      Pop      Sam Smith         Dancing With A Stranger (with Normani)
# 107812      Pop     Marshmello                                        Happier
# 107875      Pop     Pedro Capó                                  Calma - Remix
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
mask=df.nlargest(20, 'popularity')
mask
# Out:
#             genre          artist_name  \
# 9027        Dance        Ariana Grande
# 9026        Dance        Ariana Grande
# 86951         Rap          Post Malone
# 66643     Hip-Hop         Daddy Yankee
# 9028        Dance               Halsey
# 9037        Dance              Ava Max
# 86953         Rap          Post Malone
# 107810        Pop            Sam Smith
# 107812        Pop           Marshmello
# 107875        Pop           Pedro Capó
# 9048        Dance             DJ Snake
# 66607     Hip-Hop              J. Cole
# 138916  Reggaeton             Anuel Aa
# 9031        Dance        Ariana Grande
# 9040        Dance            Lady Gaga
# 66608     Hip-Hop            Meek Mill
# 66741     Hip-Hop         Paulo Londra
# 107838        Pop  Panic! At The Disco
# 138915  Reggaeton            Bad Bunny
# 138917  Reggaeton                Ozuna
#
#                                             track_name  \
# 9027                                           7 rings
# ...

# %%
unique_values = mask['key'].unique()

# Get counts of unique values
value_counts = mask['key'].value_counts()

# Convert value_counts Series to a dictionary for easy access to counts
counts_dict = value_counts.to_dict()

# Convert counts_dict to a list of counts based on unique_values order
counts = [counts_dict.get(value, 0) for value in unique_values]

plt.bar(unique_values, counts)
plt.show()

# %%
sns.set(style='whitegrid')

data={
    'Categories': unique_values, 
    'Values': counts
}
plt.figure(figsize=(8, 8))
sns.barplot(x='Categories', y='Values', data=data, palette='viridis')
plt.xlabel('Key', fontsize=12)
plt.ylabel('Number of songs', fontsize=12)
plt.title('Key vs Popularity', fontsize=14)

for index, value in enumerate(data['Values']):
    plt.text(index, value, str(value), ha='center', va='bottom', fontsize=10)
plt.show()

# %%
df
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# ...       ...                       ...
# 232716   Soul               John Legend
# 232717   Soul                     Belly
# 232719   Soul        Bobby "Blue" Bland
# 232721   Soul  Jr Thomas & The Volcanos
# 232724   Soul            Mint Condition
#
#                                     track_name                track_id  \
# 0                  C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1             Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# 2               Don't Let Me Be Lonely Tonight  0CoSDzoNIKCRs124s9uTVy
# 3               Dis-moi Monsieur Gordon Cooper  0Gc6TVm52BwZD07Ki6tIvf
# 4                                    Ouverture  0IuslXpMROHdEPvSl1fTQK
# ...

# %%
df.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')
